# %% [markdown]
# <a href="https://colab.research.google.com/github/estrella-celeste/ColabNoteboook/blob/main/Finished_Unit3ExercisesSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "preliz[full,notebook]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.2 MB/s eta 0:00:00
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.9/509.9 kB 23.2 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.10.0
#     Uninstalling nbclient-0.10.0:
#       Successfully uninstalled nbclient-0.10.0
# ...

# %%
import preliz as pz

# %% [markdown]
# # Unit 3 Exercises: Delightfully Diverse Distirbutions
#
# Use these exercises as a chance to explore the probability distributions (dists) from the pymc and preliz libraries. [Moments](https://en.wikipedia.org/wiki/Moment_(mathematics)), the main subject of these exercises, are a great way to describe dists, but there's another  way: [maximum entropy](https://en.wikipedia.org/wiki/Maximum_entropy_probability_distribution#Other_examples), which  we'll cover in a later unit.
#
# Here's what we'll cover in this Unit's exercises:
# - The first four moments: mean, variance, skew, and kurtosis, as well as the support.
# - Single variable continuous distributions.
# - Single variable discrete distriutions
#
#
# Why do we need to know this stuff? Two reasons:
# - Probability distributions are required to set priors and likelihoods in pymc.
# - Randomness and uncertainty are not well defined mathematically, but probability and probability distributions are.
#
# With that in mind, think of these exercises as an oppurtunity to explore the ways we can be uncertain, or the ways things can be random.

# %% [markdown]
# ## The First Four Moments: Mean, Variance, Skew, and Kurtosis
#
# When we talk about a probablity dist, we often care about at four things:
# - The expected value, or where a distribution is centered (mean)
# - The amount of variation from that centered value (variation)
# - Whether or not our distribution favors, leans towards, or skews towards certain values. (skew)
# - How often to expect unusually high or low values. (kurtosis)

# %% [markdown]
# ### Playing with Beta

# %% [markdown]
# **Task1**:
#
# Plot a [preliZ Beta distribution](https://preliz.readthedocs.io/en/latest/api_reference.html#preliz.distributions.beta.Beta) with $α=1$ and $β=1$.

# %%
#Plotting using the Beta distribution
pz.Beta(alpha=1, beta=1).plot_pdf()
# Out:
# <Axes: >

# %% [markdown]
# **Task2**:
#
# Find the mean, variance, skew, and kurtosis of a $Beta(1,1)$ distribution. This is the same as asking for the first four moments of a $Beta(1,1)$ distribution.
#
# *Hint*: preliZ has built in function that does this for you.

# %%
#Giving beta distribution a name (storing beta dist)
name=pz.Beta(alpha=1, beta=1)

#Finding mean, variance, skew and kurtosis
#'mvsk' stands for mean, variance, skew and kurtosis
name.moments(types= 'mvsk')
# Out:
# [0.5, 0.08333333333333333, array(0.), -1.2]

# %% [markdown]
# **Task3**:
#
# Plot the following distributions: $Beta(1,1)$, $Beta(0.9,0.9)$, $Beta(2,1)$, $Beta(1,2)$, $Beta(7,11)$, $Beta(96,42)$, $Beta(5,5)$, $Beta(500,500)$, $Beta(0.8,0.9)$.
#
# Then, determine which of those distribtuions has:
# - the largest/smallest mean
# - the largest/smallest variance
# - the largest/smallest skew
# - the largest/smallest kurtosis

# %%
#Plotting Beta(1,1)
pz.Beta(alpha=1, beta=1).plot_pdf()
# Out:
# <Axes: >

# %%
#Plotting Beta(2,1)
pz.Beta(alpha=2, beta=1).plot_pdf()
#Plotting Beta(1,2)
pz.Beta(alpha=1, beta=2).plot_pdf()
# Out:
# <Axes: >

# %%
#Plotting Beta(7,11)
pz.Beta(alpha=7, beta=11).plot_pdf()
# Out:
# <Axes: >

# %%
#Plotting Beta(96,42)
pz.Beta(alpha=96, beta=42).plot_pdf()
# Out:
# <Axes: >

# %%
#Plotting Beta(5,5)
pz.Beta(alpha=5, beta=5).plot_pdf()
# Out:
# <Axes: >

# %%
#Plotting Beta(500,500)
pz.Beta(alpha=500, beta=500).plot_pdf()
# Out:
# <Axes: >

# %%
#Plotting Beta(.8,.9)
pz.Beta(alpha=.8, beta=.9).plot_pdf()

#Plotting Beta(.9,.9)
pz.Beta(alpha=.9, beta=.9).plot_pdf()
# Out:
# <Axes: >

# %%
#Name Betas because they are long
a=pz.Beta(alpha=1, beta=1)
b=pz.Beta(alpha=2, beta=1)
c=pz.Beta(alpha=1, beta=2)
d=pz.Beta(alpha=7, beta=11)
e=pz.Beta(alpha=96, beta=42)
f=pz.Beta(alpha=5, beta=5)
g=pz.Beta(alpha=500, beta=500)
h=pz.Beta(alpha=.8, beta=.9)
i=pz.Beta(alpha=.9, beta=.9)

# %%
#Find the mean, variance, skew, and kurtosis
#Using the equation
#Putted in a long line because it doesn't give everyone
#if putted in individual lines
a.moments(types='mvsk'), b.moments(types='mvsk'), c.moments(types='mvsk'), d.moments(types='mvsk'), e.moments(types='mvsk'), f.moments(types='mvsk'), g.moments(types='mvsk'), h.moments(types='mvsk'), i.moments(types='mvsk')
# Out:
# ([0.5, 0.08333333333333333, array(0.), -1.2],
#  [0.6666666666666666, 0.05555555555555555, -0.565685424949238, -0.6],
#  [0.3333333333333333, 0.05555555555555555, 0.565685424949238, -0.6],
#  [0.3888888888888889,
#   0.012508122157244964,
#   0.1986970545340808,
#   -0.22931354359925787],
#  [0.6956521739130435,
#   0.0015231670995906488,
#   -0.14323292412687752,
#   -0.011997937472861485],
#  [0.5, 0.022727272727272728, array(0.), -0.46153846153846156],
#  [0.5, 0.00024975024975024975, array(0.), -0.005982053838484547],
#  [0.47058823529411764,
#   0.09227220299884659,
#   0.1046752255731734,
#   -1.263657274295572],
#  [0.5, 0.0892857142857143, array(0.), -1.2500000000000002])

# %% [markdown]
# *   mean
#   * Largest: Beta(alpha=96, beta=42)
#   * Smallest: Beta(alpha=1, beta=2)
# *   Variance
#   * Largest: Beta(alpha=.8, beta=.9)
#   * Smallest: Beta(alpha=500, beta=500)
# * skew
#   * Largest: Beta(alpha=1, beta=2)
#   * Smallest: Beta(alpha=.8, beta=.9)
# * kurtosis
#   *  Largest: Beta(alpha=.8, beta=.9)
#   * Smallest: Beta(alpha=500, beta=500)

# %% [markdown]
# ###Playing with other Continuous Distributions
#
# For the remaining tasks, make sure to continue to use the [preliZ documentation](https://preliz.readthedocs.io/en/latest/api_reference.html).
#
# The [wikipedia pages for each of the probability distributions](https://en.wikipedia.org/wiki/List_of_probability_distributions) are also great resources.
#
# [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/probability/probability-distributions) is another great resource as well.

# %% [markdown]
# **Task4**:
#
# Plot the pdfs of each of the following distributions: $Normal(μ=0,σ=1)$, $StudentT(ν=1,μ=0,σ=1)$, $Exponential(λ=1/2)$, $Gamma(α=2,β=1)$, $HalfStudentT(ν=1,σ1)$
#
# For the T distribution, use
#
# ```
# support=(-4,4)
# ```
# inside the plot_pdf function.

# %%
#Ploting Normal dist
pz.Normal(mu=0, sigma=1).plot_pdf()

#Not required but just want to know
#how does HalfNormal distribution looks like
pz.HalfNormal(sigma=1).plot_pdf()
# Out:
# <Axes: >

# %%
#Looking for mean, variance, skew and kirtosis
#for Normal dist
pz.Normal(mu=0, sigma=1).moments(types='mvsk')
# Out:
# [0.0, 1.0, 0, 0]

# %%
#This is for HalfNormal dist
#Looking for mean, variance, skew and kirtosis
pz.HalfNormal(sigma=1).moments(types='mvsk')
# Out:
# [0.7978845608028655,
#  0.3633802276324186,
#  0.9952717464311565,
#  0.8691773036059736]

# %%
#Plot StudentT
pz.StudentT(nu=1, mu=0, sigma=1).plot_pdf(support=(-4,4))
# Out:
# <Axes: >

# %%
#Looking for mean, variance, skew and kirtosis
pz.StudentT(nu= 1, mu=0, sigma=1).moments(types="mvsk")
# Out:
# [0.0, nan, nan, nan]

# %%
#Plot Exponential
pz.Exponential(lam=1/2).plot_pdf()
# Out:
# <Axes: >

# %%
#Looking for mean, variance, skew and kirtosis
pz.Exponential(lam=1/2).moments(types='mvsk')
# Out:
# [2.0, 4.0, 2, 6]

# %%
#Plot Gamma
pz.Gamma(alpha=2, beta=1).plot_pdf()
# Out:
# <Axes: >

# %%
#Looking for mean, variance, skew and kirtosis
pz.Gamma(alpha=2, beta=1).moments(types='mvsk')
# Out:
# [2.0, 2.0, 1.414213562373095, 3.0]

# %%
#Plot HalfStudentT
pz.HalfStudentT(nu=1, sigma=1).plot_pdf(support=(-4,4))
# Out:
# <Axes: >

# %%
#Looking for mean, variance, skew and kirtosis
pz.HalfStudentT(nu=1, sigma=1).moments(types='mvsk').support(-4,4)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-24-ead73c510fae> in <cell line: 2>()
#       1 #Looking for mean, variance, skew and kirtosis
# ----> 2 pz.HalfStudentT(nu=1, sigma=1).moments(types='mvsk').support(-4,4)
#
# /usr/local/lib/python3.10/dist-packages/preliz/distributions/distributions.py in moments(self, types)
#     192                 )
#     193             if m_t == "m":
# --> 194                 moments.append(self.mean())
#     195             elif m_t == "d":
#     196                 moments.append(self.std())
#
# /usr/local/lib/python3.10/dist-packages/preliz/distributions/halfstudentt.py in mean(self)
#     158             else:
#     159                 mean = self.sigma * (2 / np.pi) ** 0.5
# --> 160         return mean
#     161
#     162     def median(self):
#
# UnboundLocalError: local variable 'mean' referenced before assignment

# %% [markdown]
# **Task5**:
#
# What x values do the Exponenital, Gamma, HalfSutdentT, and HalfNormal functions support? What x values do the Normal and T distribution support? What x values does the Beta distribution support?

# %% [markdown]
# **Answer 5**
#
#
# *   Exponential x values = (0, infinity)
# *   Gamma x values = (0, infinity)
# *   HalfStudentT x values = (0,infinity)
# *   HalfNormal x values = (0, infinity)
# *   Normal x values = (-infinity, infinity)
# *   T dist x values = (- infinity, infinity)
# *   Beta x values = (0, 1)

# %% [markdown]
# **Task6**:
#
# Can a distribution with support $[0,∞]$ have negative (or left) skew? If so, plot that specific distribution.

# %% [markdown]
# **Answer 6**
#
# *   No I don't think it is possible for a [0, infinity] because based on the distributions above there is no negative skew.

# %% [markdown]
# **Task7**:
#
# Name a distribution that supports the real numbers with variance equal to 1, 0 skew, and 0 kurtosis.

# %% [markdown]
# **Answer7**
#
# *   The normal distribution

# %%
#normal distribution 'vsk'
#v = variance
#s = skew
#k = kurtosis
pz.Normal(mu=0, sigma=1).moments(types='vsk')
# Out:
# [1.0, 0, 0]

# %% [markdown]
# **Task8**:
#
# Name a distribution with support $(-∞,∞)$ and that has negative skew.

# %% [markdown]
# **Answer8**
#
# *  I don't think any of the above distributions can have a negative skew, especially the normal distribution since its only able to have a skew of 0.

# %% [markdown]
# ###Playing with Discrete Distributions

# %% [markdown]
# **Task9**:
#
# Plot the pdfs (techincally the pmfs) of the following distributions: $Bernoulli(p=0.7)$, $Binomial(n=10,p=0.7)$, $Poisson(λ=7)$, $Geometric(p=0.7)$, $HyperGeometric(N=50,k=35,n=15)$, $Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])$
#
# Additionally, compute the first four moments for all those distributions--except the Categorical distribution.

# %%
#Plotting Bernoulli dist
pz.Bernoulli(p=.7).plot_pdf()
# Out:
# <Axes: >

# %%
#Find the moments
#mean, variance, skew, and kurtosis
pz.Bernoulli(p=.7).moments(types='mvsk')
# Out:
# [0.7, 0.21000000000000002, -0.8728715609439692, -1.238095238095238]

# %%
#Plotting Binomial dist
pz.Binomial(n=10, p=.7).plot_pdf()
# Out:
# <Axes: >

# %%
#Finding moments
pz.Binomial(n=10, p=.7).moments(types='mvsk')
# Out:
# [7.0, 2.1000000000000005, -0.27602622373694163, -0.12380952380952379]

# %%
#Plotting Poisson dist
pz.Poisson(mu=7).plot_pdf()
# Out:
# <Axes: >

# %%
#Finding moments
pz.Poisson(mu=7).moments(types='mvsk')
# Out:
# [7.0, 7.0, 0.3779644730092272, 0.14285714285714285]

# %%
#Plotting Geometric dist
pz.Geometric(p=0.7).plot_pdf()
# Out:
# <Axes: >

# %%
#Finding moments
pz.Geometric(p=0.7).moments(types='mvsk')
# Out:
# [1.4285714285714286, 0.6122448979591838, 2.3734644158557194, 7.633333333333333]

# %%
#Plotting HyperGeometric dist
pz.HyperGeometric(N=50, k=35, n=15).plot_pdf()
# Out:
# <Axes: >

# %%
#Finding moments
pz.HyperGeometric(N=50, k=35, n=15).moments(types='mvsk')
# Out:
# [10.5, 2.25, -0.1111111111111111, -0.08983451536643026]

# %%
#Plotting Categorical dist
pz.Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4]).plot_pdf()
# Out:
# <Axes: >

# %% [markdown]
# **Task10**:
#
# Describe what processes "generate" each of the previous discrete distributions models. Also report their support.
#
# Here's a spicier way to phrase the question: describe these distributions' maximum entropy conditions in english.
#
# Hint: Make sure to read any of the: preliZ documentation, relevant wikipedia articles, or wolfram alpha.

# %% [markdown]
# **Answer10**
#
# * Discrete Probability distribution
#   * According to [wikipedia](https://en.wikipedia.org/wiki/Probability_distribution#Discrete_probability_distribution) the following disributions are known as discrete probability
#   * Used for multiple random variables and with many infinite or finite values
#   * They all use something called [probability mass function](https://en.wikipedia.org/wiki/Probability_mass_function) which gives a discrete random variable to equal a value
# *  **Bernoulli** [source 1](https://en.wikipedia.org/wiki/Bernoulli_distribution), [source 2](https://preliz.readthedocs.io/en/latest/examples/gallery/bernoulli.html)
#   *  Used in yes and no situations that's why values can be either 1 or 0. Other times, it doesn't have to be always 0 or 1.
#     * That's why this dist is a special case of the binomial and the two point distribution.
#   * Kurtosis has infinitely high and low values.
#   * The mean is the expected value or p
# *  **Binomial**
# [Source](https://en.wikipedia.org/wiki/Binomial_distribution)
#   * Used in yes or no quetions
# *  **Poisson**
#  [source](https://en.wikipedia.org/wiki/Poisson_distribution)
#   *  Expresses probability of a given # if events in a fixed interval
#     * Examples would be radioactive decay
#   *Is a max-entropy distribution (
# *  **Geometric**
# [source](https://en.wikipedia.org/wiki/Geometric_distribution)
#   * Shows the first success of an infinite sequence of Bernoulli trials
#   * Entropy increases as the probability decreases which shows a greater uncertainty of success.
# *  **HyperGeometric**
# [source](https://en.wikipedia.org/wiki/Hypergeometric_distribution#:~:text=In%20probability%20theory%20and%20statistics,that%20contains%20exactly%20objects%20with)
#   *
# *  **Categorical**
# ([Source 1](https://en.wikipedia.org/wiki/Categorical_distribution), and [Source 2](https://en.wikipedia.org/wiki/Probability_distribution#Discrete_probability_distribution) )
#   * Used for random variables with finite set values
